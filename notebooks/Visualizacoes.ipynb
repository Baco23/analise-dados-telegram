# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = pd.read_excel("../data/raw/Dados_Mega_Sena_1.xlsx", index_col=0)
file
# Out:
#             N1  N2  N3  N4  N5  N6  Viz+1d1  Viz+1d2  Viz+1d3  Viz+1d4  ...  \
# Date                                                                    ...
# 1996-03-11   4   5  30  33  41  52        5        6       31       34  ...
# 1996-03-18   9  37  39  41  43  49       10       38       40       42  ...
# 1996-03-25  10  11  29  30  36  47       11       12       30       31  ...
# 1996-04-01   1   5   6  27  42  59        2        6        7       28  ...
# 1996-04-08   1   2   6  16  19  46        2        3        7       17  ...
# ...         ..  ..  ..  ..  ..  ..      ...      ...      ...      ...  ...
# 2022-01-05   9  41  42  46  47  54       10       42       43       47  ...
# 2022-01-08   2   7   9  25  41  49        3        8       10       26  ...
# 2022-01-12   1   5  12  13  17  31        2        6       13       14  ...
# 2022-01-15  15  17  20  35  37  43       16       18       21       36  ...
# ...

# %%
file = pd.DataFrame(["Dezenas", "Linhas"])
file
# Out:
#          0
# 0  Dezenas
# 1   Linhas
